# %%
import urllib.request
from bs4 import BeautifulSoup
import csv

url = 'https://cafe.naver.com/firenze.cafe'
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="requiresActiveX=true" http-equiv="X-UA-Compatible"/>
# <title>[À¯¶û]À¯·´¿©ÇàÀÇµçµçÇÑµ¿¹ÝÀÚ : ³×ÀÌ¹ö Ä«Æä</title>
# <link href="/favicon.ico?2" rel="shortcut icon" type="image/x-icon"/>
# <meta content="always" name="referrer">
# <link href="/static/css/main/css/mycafe-common-1576065615000-73571.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/mycafe-layout-1566280818000-81973.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/mycafe-main-1578377047000-247232.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/widget-1545208501000-14621.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/line_sticker-1545208501000-9453.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/comment-1558431787000-17199.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/moz_fix-1545208501000-1454.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/map/cafe_map-1545208501000-14563.css" rel="stylesheet" type="text/css"/>
# <style id="cafeCss" type="text/css">
# /*sub*/
# body {background-color: #ffffff;background-image: none;background-repeat: repeat;}
#
# #main-area select,#main-area textarea,#main-area .list-search input {
# 	background-color: #ffffff;
# 	border: 1px solid #e5e5e5 !important;
# }  /*body backgroundcolor input000*/
# #main-area .border-sub {
# 	border-color: #e5e5e5;
# }  /* 333 list-line*/
# #main-area .board-line {
# 	background-color: #e5e5e5;
# }  /* 333 list-line*/
# #main-area .board-text {
# 	color: #e5e5e5;
# }
#
# #main-area .cafebook-line {
# 	background-color: #FF5555;
# }
#
# #main-area .skin-bgcolor {
# 	background-color: #ffffff;
# 	background-image: none;
# 	background-repeat: repeat;
# }
#
# #main-area #sub-tit {
# 	background-image:
# 		url(https://cafe.pstatic.net/style/s02_01/sub-tit-bg.gif);
# }
#
# #main-area .sub-tit-bottom {
# 	background-image:
# 		url(https://cafe.pstatic.net/style/s02_01/sub-tit-bg.gif);
# }
#
# #main-area .bg-color {
# 	background-color: #f9f9f9;
# }
#
# #main-area .sub-tit-color {
# 	color: #5269a3;
# }
#
# #main-area .list-tab li.selected {
# 	background-color: #ffffff;
# }  /*body backgroundcolor*/
# #main-area .btn span {
# 	background-image: url(https://cafe.pstatic.net/style/s02_01/btn-bg.gif)
# 		;
# }
#
# #main-area .btn p {
# 	background-image: url(https://cafe.pstatic.net/style/s02_01/btn-bg.gif)
# 		;
# }
#
# #main-area .btn2 span {
# 	background-image: url(https://cafe.pstatic.net/style/s02_01/btn-bg2.gif)
# 		;
# }
#
# #main-area .btn2 p {
# 	background-image: url(https://cafe.pstatic.net/style/s02_01/btn-bg2.gif)
# 		;
# }
#
# #main-area
# .btn_wide span{background-image:url(https://cafe.pstatic.net/style/s02_01/btn_wide.gif)}
# #main-area
# .btn_wide p{background-image:url(https://cafe.pstatic.net/style/s02_01/btn_wide.gif)}
# #main-area
# .btn_scroll{background-image:url(https://cafe.pstatic.net/style/s02_01/btn_scroll.gif)}
#
# #cafe-footer {
# 	border-top-color: #e5e5e5;
# }  /* 333 list-line*/ /*sub*/
# #cafe-body-skin {
# 	background-image: none;
# 	background-position: 0 0;
# }  /*skin-background*/
# #cafe-icoinfo .tcol-c {
# 	color: #666666;
# }  /*222*/
# #required-notice .notice {
# 	color: #666666;
# }  /*222*/
# #front-cafe a {
# 	color: #666666;
# }  /*222*/
# #group-box-area input {
# 	background-color: #ffffff !important;
# }  /*body backgroundcolor*/
# #linked-member .group-list {
# 	background-color: #EFEFEF;
# 	border-color: #BEBEBE;
# }  /*body backgroundcolor input000 */ /*gnb-menu */
# #gnb-menu a, #gnb-menu .view_mobile, #gnb-menu a.gnb_my .gnb_name {
# 	color: #666666;
# }  /*222*/
# #gnb-menu img.tcol-c {
# 	background-color: #666666;
# }  /*222*/
# #gnb-menu .up-gnb, #gnb-menu .gnb_my_li.gnb_lyr_opened .gnb_my_namebox {
# 	background-image:
# 		url(https://cafe.pstatic.net/style2014/s02_01/btn-up-gnb.png)
# }
#
# #gnb-menu .down-gnb, #gnb-menu .gnb_my_li .gnb_my_namebox {
# 	background-image:
# 		url(https://cafe.pstatic.net/style2014/s02_01/btn-down-gnb.png)
# }
#
# #gnb-menu .logout {
# 	background-image:
# 		url(https://cafe.pstatic.net/style/s02_01/btn-logout.gif)
# }
#
# #gnb-menu .login {
# 	background-image:
# 		url(https://cafe.pstatic.net/style2014/s02_01/btn-login.png)
# }
#
# /* Naver GNB Icon */
# #gnb-menu .gnb_service_li a.gnb_service .gnb_icon {
#     background-image:
#     url(https://cafe.pstatic.net/style2014/s02_01/btn-service-gnb.png);filter: progid:DXImageTransform.Microsoft.AlphaImageLoader(enabled=true, sizingMethod=crop, src=https://cafe.pstatic.net/style2014/s02_01/btn-service-gnb.png);_background:none;
# }
#
# /* Naver GNB Login Button */
# #gnb-menu .gnb_bg{
#     background-color:#ffffff;
# }
#
# #gnb-menu .gnb_bdr{
#     border-color:#bebebe;
# }
#
# #gnb-menu .gnb_txt{
#     color:#666666;
# }
#
# /*widget sub*/
# #content-area .tcol-c {
# 	color: #666666;
# }  /* ccc txt-contents*/
# #content-area .tcol-t {
# 	color: #333333;
# }  /*txt-title*/
# #content-area .tcol-p {
# 	color: #ff4836;
# }  /*txt-point*/
# #content-area .group-list li img.tcol-c {
# 	background-color: #666666;
# }  /* ccc img_ico*/
# #content-area .group-mlist-line {
# 	background-color: #666666;
# }  /* ccc line*/
# #content-area .group-border {
# 	border-color: #666666;
# }  /* ccc line*/
# #content-area .box-w {
# 	background-color: #f9f9f9;
# }  /*background =reply-bg =banner-border*/
# #content-area .group-tit h4 {
# 	padding-top: 0;
# 	background-image:
# 		url(https://cafe.pstatic.net/style/s02_01/ico-widget-tit.gif);
# 	background-repeat: no-repeat;
# 	background-position: left top;
# }  /*tit*/
# #content-area .group-tit p {
# 	padding-top: 0;
# }
#
# #content-area .member-reload {
# 	background-image:
# 		url(https://cafe.pstatic.net/style/s02_01/btn-reload.gif);
# }
#
# #content-area .member-up {
# 	background-image:
# 		url(https://cafe.pstatic.net/style/s02_01/btn-up-reload.gif);
# }
#
# #content-area .member-down {
# 	background-image:
# 		url(https://cafe.pstatic.net/style/s02_01/btn-down-reload.gif);
# }
#
# #content-area .design-input {
# 	background-color: #EFEFEF;
# 	border-color: #BEBEBE;
# }  /*body backgroundcolor input000*/
# #content-area .widget-search {
# 	background-image:
# 		url(https://cafe.pstatic.net/style/s02_01/btn_widget_search.gif);
# }
#
# #ad-banner .linebox {
# 	border-color: #f9f9f9;
# }  /*background =reply-bg =banner-border*/
# #cafe-footer .m-tcol-c {
# 	color: #666666;
# }  /* 000 txt-contents*/
# #cafe-footer .m-tcol-p {
# 	color: #5269a3;
# }  /*txt-point*/
# #main-area .con_link {
# 	color: #666666;
# } /* 000 txt-contents*/
# .list-style .srch_tx{padding:6px 0 0 19px;background:url(https://cafe.pstatic.net/style2014/ic_noti.png) no-repeat 0 5px;color:#666;font-size:13px;font-weight:bold;filter: progid:DXImageTransform.Microsoft.AlphaImageLoader(enabled=true, sizingMethod=crop, src=https://cafe.pstatic.net/style2014/ic_noti.png);_background:none;letter-spacing:-1px}
# .list-btn-view{clear:both;height:67px}
# .list-btn-view .btn_link{float:right;margin-top:12px;padding-right:6px;background:url(https://cafe.pstatic.net/style2014/ico_arr2.gif) no-repeat 100% 4px;font-size:13px;font-weight:bold;color:#666;letter-spacing:-1px;text-decoration:none}
#
#
# #cafe-banner {background-image:url(https://cafefiles.pstatic.net//20090810_184/0_1249871431684_UhoEJ2_jpg/eurang.jpg);}
# #cafe-banner p {padding:14px 0 0 10px;text-align:left;font-size:11px;font-family:dotum;display:none;color:#ffffff;font-weight:bold;}
#
#
#
#
# #cafe-footer .cafe-name {display:block;}
# #cafe-footer p {font-size:12px;font-family:dotum !important;}
# #cafe-footer span {font-weight:bold;}
# #cafe-footer .m-tcol-c {font-size:12px;font-family:dotum !important;color:;}
# #cafe-footer .m-tcol-p {font-weight:bold;color:;}
#
#
#
#
# #cafe-menu .gm-tcol-c {color:#666666;}
# #cafe-menu .gm-tcol-t {color:#666666;}
# #cafe-menu .gm-tcol-p {color:#666666;}
# #cafe-menu .box-g-t {height:6px;background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/menu-bg-t.gif);}
# #cafe-menu .box-g-m {padding-top:0;padding-bottom:5px;background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/menu-bg-m.gif);}
# #cafe-menu .box-g-b {height:6px;background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/menu-bg-b.gif);}
# #cafe-menu .cafe-menu-tit {width:165px;height:27px;margin-top:0;margin-bottom:3px;background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/menu-bg-tit.gif);}
# #cafe-menu .cafe-menu-tit h3 {margin-top:10px;margin-left:10px;}
# #cafe-menu .cafe-menu-tit p {margin-top:8px;margin-right:5px;}
# #cafe-menu .cafe-menu-tit.frst{background-image:none;}
# #cafe-menu .cafe-menu-tit .up-btn {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/btn-up-menu.gif);}
# #cafe-menu .cafe-menu-tit .down-btn {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/btn-down-menu.gif);}
# #cafe-menu .cafe-menu-space {height:2px;margin-top:0;margin-right:3px;margin-bottom:0;margin-left:3px;border-top-style:solid;border-top-width:1px;border-color:#e7e7e7;}
# #cafe-menu .cafe-menu-list {margin-top:6px;margin-left:15px;margin-right:8px;}
# #cafe-menu .ico-list {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-list.gif);}
# #cafe-menu .ico-attendance {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-attendance.png);}
# #cafe-menu .ico-best {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-best.gif);}
# #cafe-menu .ico-link {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-link.gif);}
# #cafe-menu .ico-memo {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-memo.gif);}
# #cafe-menu .ico-photo {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-photo.gif);}
# #cafe-menu .ico-picture {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-picture.gif);}
# #cafe-menu .ico-tag {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-tag.gif);}
# #cafe-menu .ico-kin {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-kin.gif);}
# #cafe-menu .ico-indent {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-indent.gif);}
# #cafe-menu .ico-simple {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-simple.png);}
# #cafe-menu .ico-map {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-map.png);}
# #cafe-menu .ico-live {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-live.png);}
# #group-area .cafe-info-action .border-sub {border-color:#e5e5e5;}
# #group-area .cafe-info-action .gm-tcol-c {color:#666666;}
# #group-area .cafe-info-action .gm-tcol-t {color:#666666;}
# #group-area .cafe-info-action .gm-tcol-p {color:#ff1e1e;}
# #group-area .cafe-info-action .box-g {padding:0 0 12px 0;background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/bg_info_action.gif);}
# #group-area .cafe-info-action .info-action-tab li {height:37px;}
# #group-area .cafe-info-action .info-action-tab li a {color:#666;}
# #group-area .cafe-info-action .info-action-tab li p {margin:12px 0 0 5px;color:#666;}
# #group-area .cafe-info-action .info-action-tab li.tit-info {width:71px;padding-right:0;padding-left:0;background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/tab_group.gif);text-align:center;}
# #group-area .cafe-info-action .info-action-tab li.tit-info-on {width:71px;padding-right:0;padding-left:0;background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/tab_group_on.gif);text-align:center;}
# #group-area .cafe-info-action .info-action-tab li.tit-action {width:68px;padding-right:0;padding-left:0;background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/tab_group2.gif);text-align:center;}
# #group-area .cafe-info-action .info-action-tab li.tit-action-on {width:68px;padding-right:0;padding-left:0;background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/tab_group2_on.gif);text-align:center;}
# #group-area .cafe-info-action .info-action-tab li.tit-bookmark {width:27px;height:34px;padding:3px 3px 0 2px;background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/tab_group3.gif) no-repeat 0 0;}
# #group-area .cafe-info-action .info-action-tab li.tit-bookmark img {width:27px !important;height:28px !important;margin:0;vertical-align:middle;}
# #group-area .cafe-info-action .info-action-tab li.tit-bookmark .btn-bookmark-on {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/btn_bookmark_on.png);_filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(enabled=true, sizingMethod=crop, src=https://cafe.pstatic.net/design/menubox/menubox-263-1/btn_bookmark_on.png);_background-image:none;}
# #group-area .cafe-info-action .info-action-tab li.tit-bookmark .btn-bookmark-off {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/btn_bookmark_off.png);_filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(enabled=true, sizingMethod=crop, src=https://cafe.pstatic.net/design/menubox/menubox-263-1/btn_bookmark_off.png);_background-image:none;}
# #group-area .cafe-info-action .ia-action-data {width:163px;height:50px;border-color:#e5e5e5;border-bottom-style:solid;}
# #group-area .cafe-info-action .ia-action-data ul {margin:10px 0 0 10px;}
# #group-area .cafe-info-action .ia-action-data .grade {width:66px;padding-right:10px;}
# #group-area .cafe-info-action .ia-info-data {width:163px;border-color:#e5e5e5;border-bottom-style:solid;}
# #group-area .cafe-info-action .ia-info-data ul {margin:7px 0 1px 10px;}
# #group-area .cafe-info-action .ia-info-data ul .info-view {padding-right:10px;}
# #group-area .cafe-info-action .ia-info-data li .mlink {width:122px;}
# #group-area .cafe-info-action .ia-info-data .cafe-admin .ico-admin {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_admin.gif) no-repeat;}
# #group-area .cafe-info-action .ia-info-data .cafe-admin .ico-stat {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_stat.gif) no-repeat;}
# #group-area .cafe-info-action .ia-info-data2 {width:163px;border-color:#e5e5e5;border-bottom-style:solid;}
# #group-area .cafe-info-action .ia-info-data2 .ico_lock {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_lock.gif);}
# #group-area .cafe-info-action .ia-info-data2 .level-info {width:81px;}
# #group-area .cafe-info-action .ia-info-data2 .mem-cnt-info {width:80px;}
# #group-area .cafe-info-action .ia-info-data2 .mem-cnt-info .ico {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_cnt_mem.gif);}
# #group-area .cafe-info-action .ia-info-data3 {width:163px;margin:11px auto 7px;}
# #group-area .cafe-info-action .ia-info-data3 ul {margin:0 8px 0 10px;}
# #group-area .cafe-info-action .ia-info-data3 .ico_bkmk {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_cnt_bkmk.gif);}
# #group-area .cafe-info-action .ia-info-data3 .ico_bkmk2 {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_cnt_bkmk2_20111028.gif);}
# #group-area .cafe-info-action .ia-info-data3 .ico_mbl {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_cnt_mbl.gif);}
# #group-area .cafe-info-action .ia-info-data3 .ico_vst {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_cnt_vst.gif);}
# #group-area .cafe-info-action .ia-info-data3 .ico_wrt {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_cnt_wrt.gif);}
# #group-area .cafe-info-action .ia-info-data3 .ico_cmt {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_cnt_cmt.gif);}
# #group-area .cafe-info-action .ia-info-btn {height:30px;margin:0 4px;padding-top:3px;border-top:1px solid #e5e5e5;}
# #group-area .cafe-info-action .ia-action-link {height:25px;border-style:solid;}
# #group-area .cafe-info-action .ia-action-link .bar {margin:0 -12px 0 2px;}
# #group-area .cafe-info-action .tab-up {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/btn-up-tab.gif);}
# #group-area .cafe-info-action .tab-down {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/btn-down-tab.gif);}
# #group-area .cafe-info-action .tab-upc {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/btn-up-tabc.gif);}
# #group-area .cafe-info-action .tab-downc {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/btn-down-tabc.gif);}
# #group-area .cafe-info-action .btn-write {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/btn_write.png);_filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(enabled=true, sizingMethod=crop, src=https://cafe.pstatic.net/design/menubox/menubox-263-1/btn_write.png);_background-image:none;}
# #group-area .cafe-info-action .btn-join {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/btn_join.png);_filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(enabled=true, sizingMethod=crop, src=https://cafe.pstatic.net/design/menubox/menubox-263-1/btn_join.png);_background-image:none;}
# #group-area .cafe-info-action .cafe-join-info{position:relative;width:169px;height:26px;margin-bottom:4px;border:1px solid #bebebe;background:#f9f9f9;}
# #group-area .cafe-info-action .cafe-join-info .tcol-c {color: #666666;}
# #group-area .cafe-info-action .cafe-join-info p {border-color: #BEBEBE;}
# #group-area .cafe-info-action .cafe-join-info .tail {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ly_join_tail.gif)}
# #cafe-menu .ico-market {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-market.gif);}
# #cafe-menu .ico-book {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-book.gif);}
# #cafe-menu .ico-list-metoo {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-list-metoo.png);filter: progid:DXImageTransform.Microsoft.AlphaImageLoader(enabled=true, sizingMethod=crop, src=https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-list-metoo.png);_background:none;}
# #cafe-menu .ico-calendar {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-calendart.gif);}
# #cafe-menu .ico-app {background-image:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico-m-app.gif);}
# #cafe-menu .ico-cafe-kin {background:url(https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_cafe_kin.png) no-repeat;_background:none;_filter:progid:dximagetransform.microsoft.alphaimageloader(src='https://cafe.pstatic.net/design/menubox/menubox-263-1/ico_cafe_kin.png', sizingmethod='crop')}
#
#
#
#
# #widget-count {height:27px;background-image:url(https://cafe.pstatic.net/widget/counter/0101_back.gif);}
# #widget-count .today {width:80px;text-align:left;}
# #widget-count .cnt1 {margin:7px 0 0 39px;font-family:tahoma;font-size:10px;font-weight:bold;color:#616161;}
# #widget-count .total {width:165px;text-align:left;}
# #widget-count .cnt2 {margin:7px 0 0 108px;font-family:tahoma;font-size:10px;font-weight:bold;color:#616161;}
#
#
#
#
#
#
# #special-menu {background-image:url(https://cafe.pstatic.net/style/s06_01/sepcial-menu-bg.gif);background-color:transparent;border-width:0;border-color:#cccccc;border-style:solid;}
# #special-menu .box-special-menu {height:40px;}
# #special-menu .special-menu {width:910px;overflow:hidden;position:relative;margin-left:10px;}
# #special-menu .special-menu li.default {margin-left:0;height:40px;background-image:url(https://cafe.pstatic.net/style/s06_01/sepcial-menu-line.gif);}
# #special-menu .special-menu li.selected .last {background-position:-2px;}
# #special-menu .special-menu li.selected p {padding-right:0;margin-left:0;background-position:right center;padding-left:0;margin-right:0;background-image:url(https://cafe.pstatic.net/style/s06_01/sepcial-menu-line.gif);height:40px;}
# #special-menu .special-menu li.selected {margin-right:0;background-position:right center;background-color:transparent;margin-left:0;background-image:none;}
# #special-menu .special-menu li span {display:none;color:#000000;margin-top:11px;}
# #special-menu .special-menu .off {margin-top:15px;margin-right:11px;margin-left:11px;color:#000000;}
# #special-menu .special-menu .on {padding-top:0;margin-top:15px;margin-right:11px;margin-left:11px;color:#855fa8;}
#
#
#
#
# #widget-weather {height:81px;background:url(https://cafe.pstatic.net/widget/weather2/weather_2_s_bg.png) no-repeat;filter: progid:DXImageTransform.Microsoft.AlphaImageLoader(enabled=true, sizingMethod=crop, src=https://cafe.pstatic.net/widget/weather2/weather_2_s_bg.png);_background:none;}
# #widget-weather .today {top:19px;left:3px;}
# #widget-weather .tomorrow {top:19px;left:93px;}
# #widget-weather .today-temperature {display:block;width:50px;top:63px;left:28px;color:#ff1800;font-size:22px;text-align:right;}
# #widget-weather .today-txt {display:block;top:71px;left:19px;color:#515151;}
# #widget-weather .tomorrow-temperature {display:block;width:50px;top:63px;left:121px;color:#a9a9a9;font-size:22px;text-align:right;}
# #widget-weather .tomorrow-txt {display:block;top:71px;left:115px;color:#515151;}
# #widget-weather .area {width:90px;color:#8b8b8b;text-align:left;top:0;left:16px;}
#
#
# #widget-currency .skin-1 {background-image:url(https://cafe.pstatic.net/widget/currency2/exchangecon_8_1.gif);}
# #widget-currency .skin-2 {display:none;background-image:url(https://cafe.pstatic.net/widget/currency2/exchangecon_8_2.gif);}
# #widget-currency .bg-head h3 a {position:absolute;top:0;right:0;}
# #widget-currency .bg-head h3 img {width:56px;height:23px;}
# #widget-currency .bg-head h3.on {display:none;}
# #widget-currency .bg-body h3 {display:block;top:30px;left:15px;color:#a3a3a3;font-size:20px;}
# #widget-currency .bg-body h3 span {color:#a3a3a3;font-size:16px;}
# #widget-currency .rate-con {display:block;width:105px;text-align:right;top:29px;left:50px;color:#fc9f61;font-size:19px;}
# #widget-currency .buy {display:block;width:45px;text-align:left;top:63px;left:120px;color:#5b5b5b;}
# #widget-currency .sell {display:block;width:45px;text-align:left;top:76px;left:120px;color:#5b5b5b;}
# #widget-currency .calculation input {color:#8b8b8b;}
# #widget-currency .result input {color:#474949;}
# #widget-currency .country {display:none;top:0;left:0;}
# #widget-currency .nation select {background-color:#ffffff;color:#8b8b8b;}
#
#
# #widget-bean .widget-bean {padding-top:105px;background-image:url(https://cafe.pstatic.net/widget/happybean/bg-been-d-4-t.gif);}
# #widget-bean .sub-widget-bean {padding:0 12px;background-image:url(https://cafe.pstatic.net/widget/happybean/bg-been-d-4-b.gif);}
# #widget-bean p {margin:0 0 4px 0;}
# #widget-bean p a {color:#607331;font-weight:bold;}
# #widget-bean .gather {margin:0 16px 5px 0;color:#89995f;font-size:10px;font-weight:bold;text-align:right;letter-spacing:-1px;}
# #widget-bean .participation {margin:0 16px 11px 0;color:#89995f;font-size:10px;font-weight:bold;text-align:right;letter-spacing:-1px;}
# #widget-bean .bean-btns {padding:0 0 11px 0;}
# #widget-bean .btn-saving {width:71px;height:19px;margin-right:5px;background-image:url(https://cafe.pstatic.net/widget/happybean/btn-been-d-4-saving.gif);}
# #widget-bean .btn-put-in {width:71px;height:19px;background-image:url(https://cafe.pstatic.net/widget/happybean/btn-been-d-4-put-in.gif);}
# #widget-bean .btn-saving-off {width:71px;height:19px;margin-right:5px;background-image:url(https://cafe.pstatic.net/widget/happybean/btn-been-d-4-saving-off.gif);}
# #widget-bean .btn-put-in-off {width:71px;height:19px;background-image:url(https://cafe.pstatic.net/widget/happybean/btn-been-d-4-put-in-off.gif);}
#
#
# #main-area .m-tcol-c {color:#666666;}
# #main-area #tbody td {color:#666666;}
# #main-area #tbody th {color:#666666;}
# #main-area .m-tcol-t {color:#666666;}
# #main-area .m-tcol-p {color:#ff1e1e;}
# #main-area .board-box img.tcol-c {background-color:#666666;}
# #main-area .board-box-line {background-color:#666666;}
# #main-area .board-box-line-dashed {border-color:#666666;}
# #main-area .list-tit {height:29px;background-color:transparent;border-width:0;border-style:solid;border-color:#cccccc;background-image:url(https://cafe.pstatic.net/style/s01_01/list-tit-bg.gif);margin-right:0;}
# #main-area .list-tit .inbox {width:8px;height:29px;background-image:none;display:none;}
# #main-area .list-tit h3 {margin-top:7px;padding-left:10px;font-size:14px;background-image:none;}
# #main-area .list-tit span {margin-top:7px;margin-right:8px;background-image:url(https://cafe.pstatic.net/style/s01_01/btn-more.gif);}
# #main-area .ico-list-notice {background-image:url(https://cafe.pstatic.net/style/s01_01/ico-list-notice.gif);}
# #main-area .ico-list-recomm {background-image:url(https://cafe.pstatic.net/style/s01_01/ico-list-recomm.gif);}
# #main-area .ico-list-info {background-image:url(https://cafe.pstatic.net/style/s01_01/ico-list-info.gif);}
# #main-area .ico-list-event {background-image:url(https://cafe.pstatic.net/style/s01_01/ico-list-event.gif);}
# #main-area .ico-list-faq {background:url(https://cafe.pstatic.net/style/skin/skin_faq_s01.gif) no-repeat 0 0;}
# #main-area .ico-recomm {background:url(https://cafe.pstatic.net/style/skin/skin_recomm_s01.gif) no-repeat 0 0;}
# #main-area .ico-solution {background:url(https://cafe.pstatic.net/style/skin/skin_solution_s01.gif) no-repeat 0 0;}
# #main-area .ico-question-select {background:url(https://cafe.pstatic.net/style/skin/qa_ico_s01_01.gif) no-repeat 0 0;}
# #main-area .ico-book {background-image:url(https://cafe.pstatic.net/style/s01_01/ico-m-book.gif);}
# #main-area .kin_activity_area .cnt_answer{background:url(https://cafe.pstatic.net/style/s01_01/ico_cafekin_answer.png) no-repeat;_background:none;filter: progid:DXImageTransform.Microsoft.AlphaImageLoader(enabled=true, sizingMethod=crop, src=https://cafe.pstatic.net/style/s01_01/ico_cafekin_answer.png);_background:none;_filter:progid:dximagetransform.microsoft.alphaimageloader(src='https://cafe.pstatic.net/style/s01_01/ico_cafekin_answer.png', sizingmethod='crop')}
# #main-area .kin_activity_area .cnt_adopt{background:url(https://cafe.pstatic.net/style/s01_01/ico_cafekin_adopt.png) no-repeat;_background:none;filter: progid:DXImageTransform.Microsoft.AlphaImageLoader(enabled=true, sizingMethod=crop, src=https://cafe.pstatic.net/style/s01_01/ico_cafekin_adopt.png);_background:none;_filter:progid:dximagetransform.microsoft.alphaimageloader(src='https://cafe.pstatic.net/style/s01_01/ico_cafekin_adopt.png', sizingmethod='crop')}
#
#
#
#
#
# </style>
# <script>
# var g_sUserId = "";
# var g_sGroupId = "false";
# var g_sCafeHome = "https://cafe.naver.com/" + "firenze";
# var g_sClubId = "10209062";
# var g_mobileWebLink = "https://m.cafe.naver.com/firenze";
#
# var g_sCafeThumbUrl = 'https://cafethumb.pstatic.net';
# var g_sUpcafeUrl = 'https://up.cafe.naver.com';
# var g_sCafeUrl = "https://cafe.naver.com";
# var g_sCafeImgUrl = 'https://cafe.pstatic.net';
# var g_sCafeFileUrl = 'https://cafefiles.pstatic.net';
# var g_sItem2Url = 'https://item2.naver.com';
# var g_sLoginUrl = "http://nid.naver.com";
# var g_sNidHttps = 'https://nid.naver.com';
# var g_sCafeSectionUrl = "https://section.cafe.naver.com";
# var g_sNdriveHttps = "https://cloud.naver.com";
# var g_sKin = "http://kin.naver.com";
# var g_sLogOutReturnUrl = "https://nid.naver.com/nidlogin.login?mode=form&svctype=40960&id=&url=https://cafe.naver.com/LoginCheck.nhn?m=login";
# var g_sCafeTalk = 'https://talk.cafe.naver.com';
# var g_sGfmarketDomain = 'http://m.gfmarket.naver.com';
# var g_sGfmarketThumbnailDomain = 'https://storep-phinf.pstatic.net';
# var g_sPhotoInfraUploadDomain = 'cafe.upphoto.naver.com';
# var g_sDThumbUrl = 'https://dthumb-phinf.pstatic.net/?src=';
# var g_sNaverStatUiUrl = 'https://cafe.stat.naver.com/cafe';
# var g_sBAStatDomain = 'https://scv.band.us';
# var g_sApigwUrl = 'https://apis.naver.com';
# var g_sCafeHomePcUrl = 'https://section.cafe.naver.com';
#
# var g_sNicknameRegex = /([a-zA-Z0-9¤¡-ÆR\_\s]+)/gi;
# var g_mainIframeWidth = '773';
# </script>
# <script src="/static/js/mycafe/javascript/jindo.all-1545208501000-90818.js" type="text/javascript"></script>
# <script src="/static/js/mycafe/javascript/cssquery-1545208501000-18676.js" type="text/javascript"></script>
# <script src="/static/js/mycafe/javascript/jindo/common_util-1545208501000-4535.js" type="text/javascript"></script>
# <script src="/static/js/mycafe/javascript/widget-1545208501000-2800.js" type="text/javascript"></script>
# <script src="/static/js/mycafe/javascript/cafe_common-1579154032000-28510.js" type="text/javascript"></script>
# <script src="/static/js/mycafe/javascript/cafe_eventutil-1545208501000-2096.js" type="text/javascript"></script>
# <script src="/static/js/mycafe/javascript/autosourcing-1545208501000-8747.js" type="text/javascript"></script>
# <script src="/static/js/mycafe/javascript/AjaxRequest-1545208501000-16024.js" type="text/javascript"></script>
# <script src="/static/js/mycafe/javascript/click/clickcr-1545208501000-6201.js" type="text/javascript"></script>
# <script src="/static/js/mycafe/javascript/lcslog-1545208501000-26709.js" type="text/javascript"></script>
# <script charset="utf-8" src="/static/js/mycafe/javascript/tablet/TabletHandler-1545208501000-2403.js" type="text/javascript"></script>
# <script charset="utf-8" src="/static/js/mycafe/javascript/lib/skipNavigationWebkit-1545208501000-907.js" type="text/javascript"></script>
# <script charset="utf-8" src="/static/js/mycafe/javascript/editor/MainLocalStorage-1581317175000-1619.js" type="text/javascript"></script>
# <script charset="utf-8" src="/static/js/mycafe/javascript/IframeHandler-1545208501000-2279.js" type="text/javascript"></script>
# <script charset="utf-8" src="/static/js/mycafe/javascript/PowerCafeNoticeLayer-1546601018000-1880.js" type="text/javascript"></script>
# <script charset="utf-8" src="/static/js/mycafe/javascript/lib/da/ActiveViewPC-1564056018000-8868.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var nsc = "cafe.mycafe";
# 	var oCL = new Ju.controlLayer(); // Ju.controlLayer() Å¬·¡½º¸¦ oCL Àü¿ª º¯¼ö¿¡ ÇÒ´çÇÔ
# 	var LH = new LH_create();
# 	window.onload = LH_exec;
#
# 	if (false==true) {
# 		blockMouseRight();
# 	}
# //--------------- Mac Safari bug --------------------------
# function controlTagClickEvent(e){
# 	if(!!$Agent() && $Agent().macSafari ){
# 	 	var controlTagName = ["a"];
# 	 	var elTarget = e.element,
# 	 		sTargetUrl = null;
# 	 	if(elTarget != null ){
# 	 		if(elTarget.tagName.toLowerCase() == "a" && elTarget.href+"" != document.location.href+"#"){
# 	 			elTarget.target="_top";
# 	 		}
# 	 		return ;
# 	 	}
# 	}
# }
#
# (function() {
# 	if(!!$Agent() && $Agent().macSafari ){
# 		Event.register(window, "load", function() {
# 			if($('main-area') != null){
# 				Event.register($('main-area'), 'click', this.controlTagClickEvent.bindForEvent(this));
# 			}
# 		});
# 	}
# })();
# //--------------- Mac Safari bug End --------------------------
# </script>
# <meta content="mycafe_main" name="decorator">
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <script type="text/javascript">
# </script>
# <script type="text/javascript">
# 	LH.add("parentResizeIframe('cafe_main')");
# </script>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/ssp/ssp.web.sdk.js" type="text/javascript"></script>
# <script>
#
# 	var unitId = "pc_cafe_wrt";
#
# 	var divId = "floatingda_content";
#
# 	var spwp = spwp || {};
# 	spwp.cmd = spwp.cmd || [];
#
#
# 	spwp.cmd.push(function () {
# 		spwp.setConfig({
# 			enablePersistAd: true
# 		});
#
# 		var adUnits = [{
# 			unitId: unitId,
# 			divId: divId
# 		}];
#
# 		spwp.addAdUnits(adUnits);
# 	});
#
#
#
# 	function showHappybeanFloatingBanner() {
# 		spwp.cmd.push(function () {
# 			spwp.requestAds({
# 				adUnitIds: [unitId]
# 			});
# 		});
#
#
# 		spwp.cmd.push(function () {
# 			spwp.renderAd(divId);
# 		});
# 	}
#
#
# 	function hideHappybeanFloatingBanner() {
# 		document.getElementById(divId).innerHTML = ""
# 	}
# </script>
# <script charset="UTF-8" src="/static/js/mycafe/common/groupssp/plug/ScriptGroupSSPAdvert-1577761219000-1860.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var oGroupSSPAdvertReporter = new cafe.GroupSspAdvertReporter();
# </script>
# <script type="text/javascript">
#     function stickyEventHandler(target, topOffset) {
#         var scrollTop = jQuery(window).scrollTop();
#         var oElement = jQuery(target);
#
#         if (scrollTop >= topOffset) {
#             oElement.addClass('type_fixed');
#         } else {
#             oElement.removeClass('type_fixed');
#         }
#     }
#
#     function initSticky(target, scrollTop, topOffset) {
#         if (scrollTop >= topOffset) {
#             stickyEventHandler(target, topOffset);
#         }
#     }
#
#     function sticky(target) {
#         var scrollTop = jQuery(window).scrollTop(),
#             topOffset = jQuery(target).offset().top;
#
#         initSticky(target, scrollTop, topOffset);
#
#         jQuery(window).scroll(function () {
#             stickyEventHandler(target, topOffset);
#         });
#     }
#
#     function isPlugFloatingAdvertExposureTimeExpired() {
#         var localStorageKey = oMainLocalStorage.PC_PLUG_FLOATING_ADVERT_EXPOSURE_TIME;
#         var exposureTimeStr = oMainLocalStorage.getLocalStorage(localStorageKey);
#
#         if (exposureTimeStr == null || typeof exposureTimeStr == "undefined") {
#             return true;
#         }
#
#         try {
#             return Date.parse(exposureTimeStr) - new Date() < 0;
#         } catch(e) {
#             return true;
#         }
#     }
#
#     function updatePlugFloatingAdvertExposureTime() {
#         var currentDate = new Date();
#         var minutes = 60000;
#         oMainLocalStorage.setLocalStorage(oMainLocalStorage.PC_PLUG_FLOATING_ADVERT_EXPOSURE_TIME, new Date(currentDate.getTime() + 10 * minutes));
#     }
#
#     function clickCloseFloatingAdvert() {
#         updatePlugFloatingAdvertExposureTime();
#         var elFloatingBannerDiv = parent.document.getElementById('plugFloatingBannerWrapper');
#         elFloatingBannerDiv.style.display = 'none';
#     }
#
#     var reportFuc = null;
#
#     /**
# 	 * floatingAdvert¸¦ È£ÃâÇÑ´Ù. (iframe ³»ºÎ°¡ reloadµÉ ¶§¸¶´Ù È£Ãâ)
#      */
#     function callPlugFloatingAdvert() {
#         try {
#             var cafeId = 10209062;
#             var iframeUrl = document.getElementById("cafe_main").contentWindow.location.href.split("?")[0];
#
#             if (cafeId == null || typeof cafeId == "undefined") {
#                 return;
#             }
#
#             if (parent.document.getElementById('plugFloatingBanner') == null) {
#                 return;
#             }
#
#             var elPlugFloatingBannerDiv = document.getElementById("plugFloatingBannerDiv");
#             if (reportFuc != null) {
#                 elPlugFloatingBannerDiv.removeEventListener("click", reportFuc);
#                 reportFuc = null;
#             }
#
#             var bGameDirCafe = false;
#             if (bGameDirCafe == false) {
#                 return;
#             }
#
#             if (!isPlugFloatingAdvertExposureTimeExpired()) {
#                 updatePlugFloatingAdvertExposureTime();
#                 return;
#             }
#
#             var ajax = new Ajax("/PlugFloatingAdvert.nhn?cafeId=" + cafeId + "&iframeUrl=" + iframeUrl, {
#                 method: "GET",
#                 onLoad: function (res) {
#                     var oJsonResult = JSON.parse(res.responseText);
#                     if (oJsonResult.message.status == 200) {
#                         var elFloatingBanner = parent.document.getElementById('plugFloatingBanner');
#                         var elFloatingBannerDiv = parent.document.getElementById('plugFloatingBannerWrapper');
#                         var elFloatingBannerPvUrl = parent.document.getElementById('plugFloatingBannerPvUrl');
#                         var elFloatingBannerCloseButton = parent.document.getElementById('plugFloatingBannerCloseBtn');
#
#                         elFloatingBannerDiv.style.display = 'none';
#                         elFloatingBannerPvUrl.value = "";
#                         elFloatingBannerCloseButton.style.display = 'none';
#
#                         elFloatingBanner.style.display = 'none';
#                         elFloatingBanner.removeAttribute("src");
#                         elFloatingBanner.removeAttribute("alt");
#                         elFloatingBanner.parentNode.removeAttribute('href');
#
#                         var oAdvert = oJsonResult.message.result;
#                         if (typeof oAdvert === "undefined") {
#                             return;
#                         }
#
#                         if (oAdvert.code === 'NONE' || (oAdvert.code === 'NO_BANNER' && !oAdvert.hasOwnProperty('pvUrl'))) {
#                             return;
#                         }
#
#                         elFloatingBannerPvUrl.value = oAdvert.pvUrl;
#                         elFloatingBannerDiv.style.display = 'block';
#
#                         sticky(elFloatingBannerDiv);
#
#                         if (oAdvert.code === 'OK') {
#                             elFloatingBannerCloseButton.style.display = 'block';
#
#                             elFloatingBanner.style.display = 'block';
#                             elFloatingBanner.src = oAdvert.imageUrl;
#                             elFloatingBanner.alt = oAdvert.title;
#                             elFloatingBanner.parentNode.href = oAdvert.targetUrl;
#
# 							elFloatingBanner.width = oAdvert.width;
# 							elFloatingBanner.height = oAdvert.height;
#                         }
#
#                         naver_corp_da.init("plugFloatingBannerDiv", function() {
#                             document.getElementById("plugFloatingBannerPv").src = document.getElementById("plugFloatingBannerPvUrl").value;
#                             document.getElementById("plugFloatingBannerImp").src = oJsonResult.message.result.reportUrlMap['IMP'];
#                         });
#
#                         var sspClickReportUrl = oJsonResult.message.result.reportUrlMap['CLICK'];
#
#                         reportFuc = function() {
#                             oGroupSSPAdvertReporter._report(sspClickReportUrl);
#                         };
#                         elPlugFloatingBannerDiv.addEventListener("click", reportFuc, false);
#                     }
#                         // 200 ¾Æ´Ñ °æ¿ì´Â Ã³¸®ÇÏÁö ¾ÊÀ½*/
#                 }
#             });
#         } catch (e) { // jeagleeye·Î Àü¼Û?
#         }
#     }
# </script>
# </meta></meta></head>
# <body class="">
# <div class="layer_reserve" id="reserveGameCafeLayer" style="display: none">
# <div class="layer_inner">
# <div id="sub-tit">
# <div class="title_area">
# <div class="info_tit">
# <h3 class="sub-tit-color">»çÀü¿¹¾àÇÏ°í Ä«Æä °¡ÀÔÇÏ±â</h3>
# </div>
# <p class="m-tcol-c">
#                     »çÀü¿¹¾à ¾Ë¸²µµ ¹Þ°í, Ä«Æä¿¡¼­ ÃÖ½Å ¼Ò½ÄÀ» È®ÀÎÇØº¸¼¼¿ä.
#                 </p>
# </div>
# </div>
# <div class="article-reserve">
# <div class="row">
# <div class="title_cell">
# <strong class="title type_os">ÀÌ¿ëÇÏ´Â OS¼±ÅÃ</strong>
# </div>
# <div class="info_cell">
# <div class="os_box">
# <div class="radio_box green_radio">
# <input id="ios_radio" name="radio_box" type="radio" value="ios"/>
# <label for="ios_radio">
# <span class="badge_ios"><span class="blind">IOS. Download on the App Store</span></span>
# </label>
# </div>
# <div class="radio_box green_radio">
# <input id="android_radio" name="radio_box" type="radio" value="android"/>
# <label for="android_radio">
# <span class="badge_android"><span class="blind">Android. Get it on Google Play</span></span>
# </label>
# </div>
# </div>
# </div>
# </div>
# <div class="join_noti_section">
# <ul class="list_bold">
# <li><strong>¡®µ¿ÀÇ ÈÄ »çÀü¿¹¾àÇÏ±â¡¯ ½Ã »çÀü¿¹¾à°ú ÇÔ²² Ä«Æä¿¡ °¡ÀÔµË´Ï´Ù. °ÔÀÓ Ãâ½Ã Àü Ä«Æä Å»Åð ½Ã »çÀü¿¹¾à Âü¿© ³»¿ªµµ ÇÔ²² »èÁ¦µË´Ï´Ù.</strong></li>
# <li><strong>»çÀü¿¹¾à ÇýÅÃ ¹× °ÔÀÓ Ãâ½Ã ¼Ò½ÄÀº '³×ÀÌ¹ö ÅåÅå'À¸·Î ¾È³»µå¸®¸ç, ³×ÀÌ¹ö¾ÛÀÌ ¼³Ä¡µÇ¾îÀÖÁö ¾Ê°Å³ª ·Î±×ÀÎÀÌ µÇ¾îÀÖÁö ¾ÊÀº °æ¿ì ¾Ë¸²ÀÌ Á¦°øµÇÁö ¾Ê½À´Ï´Ù.</strong></li>
# </ul>
# </div>
# <div class="btn_area">
# <a class="btn_type1" href="#" onclick="addReservationGameCafe(); return false;"><strong>µ¿ÀÇ ÈÄ »çÀü¿¹¾àÇÏ±â</strong></a>
# </div>
# </div>
# <a class="btn_ly_close" href="#" onclick="closeLayer();return false;" role="button"><span class="blind">·¹ÀÌ¾îÆË¾÷ ´Ý±â</span></a>
# </div>
# </div>
# <script type="text/javascript">
#     function closeLayer() {
#         jQuery("#reserveGameCafeLayer").css("display" , "none");
#         jQuery("#ios_radio")[0].checked = false;
#         jQuery("#android_radio")[0].checked = false;
#     }
#
#     function addReservationGameCafe() {
#         var welIosInput = jQuery("#ios_radio");
#         var welAndroidInput = jQuery("#android_radio");
#
#         if (!(welIosInput[0].checked ^ welAndroidInput[0].checked)) {
#             alert("os¸¦ ¼±ÅÃÇØÁÖ¼¼¿ä.");
#             return;
#         }
#
#         jQuery.ajax({
#             url: '/PlugReserveGameCafeAjax.nhn',
#             method: 'post',
#             data: {
#                 'cafeId': '10209062',
#                 'os': welIosInput[0].checked ? welIosInput[0].value : welAndroidInput[0].value
#             }
#         }).done(onLoadReserve).fail(onErrorReserve);
#
#         sendReservationCompleteBA('10209062');
#     }
#
#     function onLoadReserve(oRes) {
#         var oMessage = oRes.message;
#
#         if (!oMessage) {
#             alert("»çÀü¿¹¾à ½ÅÃ» Áß ¹®Á¦°¡ ¹ß»ýÇß½À´Ï´Ù. Àá½Ã ÈÄ ´Ù½Ã ½ÃµµÇØÁÖ¼¼¿ä.");
#             return;
#         }
#
#         if (oMessage.status !== '200') {
#             alert(oMessage.error.msg);
#             closeLayer();
#             return;
#         }
#
#         alert("»çÀü¿¹¾à Âü¿©°¡ ¿Ï·áµÇ¾ú½À´Ï´Ù.");
#         location.reload();
#     }
#
#     function onErrorReserve(oRes) {
#         alert(oRes.message.error.msg);
#     }
#
#     function sendReservationCompleteBA(sCafeId) {
#         oBAStatSender.send([
#             {
#                 eventType : cafe.BAStatEventType.PC_1442_167,
#                 extra : {
#                     cafe_id : sCafeId
#                 }
#             }
#         ]);
#     }
# </script>
# <div id="u_skip">
# <a class="skip" href="#cafe-menu" onclick="var t=document.getElementById('cafe-menu');t.tabIndex=-1;t.focus();return false;">°Ô½ÃÆÇ ¸ñ·Ï ¹Ù·Î°¡±â</a>
# <a class="skip" href="#main-area" onclick="var t=document.getElementById('main-area');t.tabIndex=-1;t.focus();return false;">º»¹® ¹Ù·Î°¡±â</a>
# <a class="skip" href="https://m.cafe.naver.com/firenze" id="u_skipToMobileweb">À¥ Á¢±Ù¼ºÀÌ ÁÁÀº ¸ð¹ÙÀÏ À¥¿¡¼­ »ç¿ëÇÏ°Ú½À´Ï±î?</a>
# </div>
# <h1 class="d-none">[À¯¶û]À¯·´¿©ÇàÀÇµçµçÇÑµ¿¹ÝÀÚ</h1>
# <div id="cafe-body-skin">
# <div id="cafe-body">
# <div id="naver-gnb">
# <a class="link_naver" href="http://www.naver.com"><img alt="NAVER" height="10" src="https://ssl.pstatic.net/static/cafe/icon_naver_190423.png" width="52"/></a>
# <div id="gnb-menu">
# <p class="naver-h" id="naver-h">
# <a href="https://section.cafe.naver.com">Ä«ÆäÈ¨</a>
# <img alt="" class="tcol-c" height="10" src="https://cafe.pstatic.net/cafe4/ico-blank.gif" width="1"/>
# </p>
# <div class="join-cafe off" id="button_join_cafe">
# <a href="#">°¡ÀÔÄ«Æä</a>
# <a href="#"><img alt="°¡ÀÔÄ«Æä" class="btn-join down-gnb" height="13" id="joincafeimg" src="https://cafe.pstatic.net/cafe4/hidden.gif" width="13"/></a>
# <img alt="" class="tcol-c" height="10" src="https://cafe.pstatic.net/cafe4/ico-blank.gif" width="1"/>
# </div>
# <div class="chatting-cafe" id="button_mynews_alarm">
# <a class="link_chatting" href="#">»õ±Û</a>
# <img alt="" class="tcol-c" height="10" src="https://cafe.pstatic.net/cafe4/ico-blank.gif" width="1"/>
# </div>
# <div class="chatting-cafe mynews-cafe off" id="button_mynews_activity">
# <a class="link_chatting" href="#">³»¼Ò½Ä</a>
# <img alt="" class="tcol-c" height="10" src="https://cafe.pstatic.net/cafe4/ico-blank.gif" width="1"/>
# </div>
# <div class="cc_layer_mynews" id="layer_mynews_activity" style="display: none">
# <div class="cc_mynews_header">
# <h2 class="title">³»¼Ò½Ä</h2>
# </div>
# <div class="cc_mynews_content">
# <div class="cc_mynews_none" style="display: none">
# <strong class="title">³»¼Ò½ÄÀÌ ¾ø½À´Ï´Ù.</strong>
# <p class="txt">°¡ÀÔÇÑ Ä«ÆäÀÇ È°µ¿ ¾Ë¸²°ú ´ñ±Û¾Ë¸²À»<br/>ÀÌ°÷¿¡¼­ ¸ð¾Æº¼ ¼ö ÀÖ¾î¿ä.</p>
# </div>
# <div class="cc_mynews_area" style="display: none">
# <span class="blind">ÃÖ±Ù 30ÀÏ ÀÌ³»ÀÇ ÃÖ½Å¼ø ¼Ò½ÄÀÔ´Ï´Ù.</span>
# <ul class="cc_mynews_list">
# <li id="_mynews_notice_tooltip">
# <div class="cc_mynews_notice">
# <p class="notice_txt">
#                                 ¾Ë¸²ÀÇ <span class="icon_option"></span> ¹öÆ°À» Å¬¸¯ÇÏ¸é, ¾Ë¸²À» ¼³Á¤ÇÒ ¼ö ÀÖ¾î¿ä.
#                             </p>
# <!-- [D] .btn_close Å¬¸¯ ½Ã °øÁö ·¹ÀÌ¾î´Â ¹Ì³ëÃâµÇ°Ô ÇØÁÖ¼¼¿ä~ -->
# <button class="btn_close" id="_btn_hide_mynews_notice" type="button"><span class="blind">°øÁö ´Ý±â</span></button>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="cc_layer_alert" style="display:none;">
# <strong class="blind">³»¼Ò½Ä ¾È³» ·¹ÀÌ¾îÆË¾÷</strong>
# <div class="cc_alert_content">
# <p class="txt"></p>
# </div>
# <div class="cc_alert_footer">
# <button class="cc_alert_btn" type="submit">È®ÀÎ</button>
# </div>
# </div>
# <div class="chatting-cafe">
# <a class="link_chatting" href="#" onclick="openCafeTalk();return false;">Ã¤ÆÃ</a>
# <img alt="" class="tcol-c" height="10" src="https://cafe.pstatic.net/cafe4/ico-blank.gif" width="1"/>
# </div>
# <!-- GNB ÅÛÇÃ¸´ Àû¿ëºÎ -->
# <div id="gnb">
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?1578466602000" type="text/javascript"></script>
# </div>
# <!--//GNB ÅÛÇÃ¸´ Àû¿ëºÎ -->
# <div id="layer_login" style="display:none;">
# <p><a href="#" onclick="toLoginPage()">·Î±×ÀÎÇØÁÖ¼¼¿ä</a></p>
# </div>
# <iframe frameborder="0" id="join-cafe-iframe" scrolling="no" style="overflow:hidden;display:none;" title="°¡ÀÔÄ«Æä¸ñ·Ï" width="280"></iframe>
# </div>
# <div id="cafeappInstallIntroLayer" style="display:none;position:absolute;border:1px solid #969696;background:#fff;top:25px;left:676px">
# <div style="width:252px;padding:13px 13px 10px;text-align:center">
# <p style="font-size:12px;line-height:16px;color:#333"><strong><span style="color:#2cae0c">³×ÀÌ¹ö¾Û ¾Ë¸²</span>À¸·Î <br/>Ä«Æä¾Û ¼³Ä¡ °æ·Î¸¦ Àü¼ÛÇß½À´Ï´Ù.</strong></p>
# <p style="padding:4px 0 7px;font-size:11px;line-height:16px;color:#999;letter-spacing:-1px">³×ÀÌ¹ö¾ÛÀÌ ÃÖ½Å¹öÀüÀÌ ¾Æ´Ï°Å³ª, <br/>·Î±×¾Æ¿ô »óÅÂ¿©¼­ ¾Ë¸²À» ¸ø ¹ÞÀ¸¼Ì´Ù¸é <br/>¹®ÀÚ Àü¼ÛÀ¸·Î Ä«Æä¾ÛÀ» ¼³Ä¡ÇÏ½Ç ¼öµµ ÀÖ½À´Ï´Ù.</p>
# <div style="padding-top:10px;border-top:1px solid #eeeeec;text-align:center">
# <a href="#" id="cafeappInstallIntroLayerSmsBtn" style="display:inline-block;overflow:hidden;width:116px;height:23px;margin-right:2px;background:url(https://cafe.pstatic.net/img/section/ly_cafeapp_dnld_140331.png) no-repeat 0 -34px;line-height:100px;vertical-align:top">Ä«Æä¾Û ¼³Ä¡ ¹®ÀÚ Àü¼Û</a>
# <a href="#" id="cafeappInstallIntroLayerCloseBtn" style="display:inline-block;overflow:hidden;width:35px;height:23px;background:url(https://cafe.pstatic.net/img/section/ly_cafeapp_dnld_140331.png) no-repeat 0 -60px;line-height:100px;vertical-align:top">È®ÀÎ</a>
# </div>
# </div>
# <a href="#" id="cafeappInstallIntroLayerCloseXBtn" role="button" style="display:inline-block;overflow:hidden;position:absolute;top:0;right:0;width:30px;height:30px;background:url(https://cafe.pstatic.net/img/section/ly_cafeapp_dnld_140331.png) no-repeat -136px -34px;line-height:100px;vertical-align:top">·¹ÀÌ¾î ´Ý±â</a>
# </div>
# <script type="text/javascript">
# var cafeappInstallIntroLayer = {
#     init : function(pUserLoggedIn) {
#         this.cafeappInstallIntroLayer = $('cafeappInstallIntroLayer');
#         this.cafeappInstallIntroLayerSmsBtn = $('cafeappInstallIntroLayerSmsBtn');
#         this.cafeappInstallIntroLayerCloseBtn = $('cafeappInstallIntroLayerCloseBtn');
#         this.cafeappInstallIntroLayerCloseXBtn = $('cafeappInstallIntroLayerCloseXBtn');
#         this.userloggedIn = pUserLoggedIn;
#         this.bindEvent();
#     },
#     bindEvent : function() {
#         Event.register(this.cafeappInstallIntroLayerSmsBtn, 'click', this.popupSms.bindForEvent(this));
#         Event.register(this.cafeappInstallIntroLayerCloseBtn, 'click', this.hideLayer.bindForEvent(this));
#         Event.register(this.cafeappInstallIntroLayerCloseXBtn, 'click', this.hideLayer.bindForEvent(this));
#     },
#     hideLayer : function(we) {
#         oCL.hide(this.cafeappInstallIntroLayer);
#         we.stop();
#     },
#     popupSms : function(we) {
#     	openPopupSendURL();
#         oCL.hide(this.cafeappInstallIntroLayer);
#         we.stop();
#     },
#     showLayer : function(event, nTop, nLeft) {
#
#     	if(!this.userloggedIn) {
#     		popupLoginPage(document.location);
#     		return;
#     	}
# ...
#         var width  = opt.width;
#         var height = opt.height;
#         var happybeanPopup = window.open(
#             opt.url,
#             'happybean',
#             'width='+opt.width+',height='+opt.height+',directories=no,location=no,menubar=no,scrollbars=yes,status=no,toolbar=no,resizable=no'
#         );
#
#         happybeanPopup.focus();
#     },
#     doNewWindow : function(url) {
#         var happybeanWindow = window.open(
#             url,
#             'happybean',
#             'directories=yes,location=yes,menubar=yes,scrollbars=yes,status=yes,toolbar=yes,resizable=yes'
#         );
#
#         happybeanWindow.focus();
#     }
# });
#
# new widgetHappybean({
#     bUserAdmin : false,
#     bUser : ''
# });
#
# </script>
# <li class="box-ww">
# <div id="widget-weather"></div>
# </li>
# <li class="box-ww">
# <div id="widget-count">
# <h3><span>Ä«¿îÅÍ</span></h3>
# <p class="today"><span class="txt">Today</span><span class="cnt1" id="todayVisitCount"></span></p>
# <p class="total"><span class="txt">Total</span><span class="cnt2" id="totalVisitCount"></span></p>
# </div>
# </li>
# <li class="box-ww">
# <div id="widget-currency">
# <div class="skin-1" id="widget_exchange0"><!-- È¯À²Á¤º¸ --></div>
# <div class="skin-2" id="widget_exchange1"><!-- È¯À²°è»ê±â --></div>
# </div>
# </li>
# </ul>
# <div class="banner_chatbot">
# <a class="chatbot" href="https://talk.naver.com/ct/wc63k2"><img alt="±Ã±ÝÇÑ°Ô ÀÖÀ» ¶© Ä«Æä ½º¸¶Æ®º¿" height="55" src="https://ssl.pstatic.net/static/cafe/banner_chatbot.png" width="171"/></a>
# </div>
# </div>
# <div class="fr" id="main-area">
# <input id="gateOpen" type="hidden" value="1">
# <input id="searchviewtype" type="hidden" value="title">
# <iframe allowfullscreen="" allowtransparency="true" frameborder="0" height="100%" id="cafe_main" marginheight="0" marginwidth="0" name="cafe_main" scrolling="no" src="about:blank" title="Ä«Æä ¸ÞÀÎ" width="773"></iframe>
# <script type="text/javascript">
#                                 $("cafe_main").src = "//cafe.naver.com/MyCafeIntro.nhn?clubid=10209062";
# 							</script>
# </input></input></div>
# </div>
# <div id="cafe-footer">
# <p class="cafe-name m-tcol-c">³×ÀÌ¹ö Ä«Æä <span class="m-tcol-p">[À¯¶û]À¯·´¿©ÇàÀÇµçµçÇÑµ¿¹ÝÀÚ</span></p>
# </div>
# <div id="floatingda_content" style="z-index:101; position:absolute; top:100px; right:10px;"></div>
# </div>
# <a class="blind" href="#" onfocus="var t=document.getElementById('u_skip');t.tabIndex=-1;t.focus();return false" style="visibility:visible">ÄÜÅÙÃ÷ »ó´Ü</a>
# </div>
# <input id="questionct" type="hidden" value="block">
# <iframe frameborder="0" height="0" id="cafe_check" name="cafe_check" title="Ä«ÆäÈ®ÀÎ" width="0"></iframe>
# <form action="/CafeApplyCheck.nhn" id="cafeApply_check" method="post" style="margin:0;padding:0;" target="cafe_check">
# <input name="clubid" type="hidden" value="10209062"/>
# <input name="email" type="hidden" value=""/>
# <input name="alreadyMemberPopup" type="hidden" value="true"/>
# <input id="redirectwrite" name="redirectwrite" type="hidden" value=""/>
# <input id="redirectUrl" name="redirectUrl" type="hidden" value=""/>
# </form>
# <form name="answerSaveFrm" style="display:none;">
# </form>
# <form name="nicknameSaveFrm">
# <input id="cafeTempApplyNickname" name="cafeTempApplyNickname" type="hidden" value=""/>
# </form>
# <script charset="UTF-8" src="/static/js/mycafe/javascript/lib/nanoajax/nanoajax.min-1545208501000-685.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#     setMinSize(773, -1);
#     setMaxSize(773, -1);
#
#
#     function moveIframePage(url) {
#         $("cafe_main").src = url;
#     }
#
#
#
#     function suggestJoin() {
#
#
#         var clubname = "[À¯¶û]À¯·´¿©ÇàÀÇµçµçÇÑµ¿¹ÝÀÚ";
#         if (confirm('Ä«Æä¸â¹ö¸¸ ÀÌ¿ëÇÒ ¼ö ÀÖ´Â ±â´ÉÀÔ´Ï´Ù.\n' + clubname.replace(/&lt;/g, "<").replace(/&gt;/g, ">") + ' Ä«Æä¿¡ °¡ÀÔÇÏ½Ã°Ú½À´Ï±î?')) {
#             joinCafe();
#         }
#     }
#
#
#
#
# </script>
# <script type="text/javascript">
#     var oPowerCafeNoticeLayer = new PowerCafeNoticeLayer({
#         aNotices : [
#             {'name' : 'powerCafeNotice', 'show' : false},
#             {'name' : 'powerCafeCandidateNotice', 'show' : false}
#         ]
#     });
# </script>
# <link href="/static/css/main/css/ip_layer_2-1545208501000-2931.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# 	function openLoginLayer() {
# 		var loginCheckOk = "https://cafe.naver.com/LoginCheck.nhn?m=login";
# 		checkFrame.location.replace("https://nid.naver.com/nidlogin.login?mode=form&svctype=40960&id=&url="+loginCheckOk);
#
#
# 		var layerScrollTop = parent.document.getElementsByTagName('HTML')[0].scrollTop;
#         var layerClientHeight = parent.document.getElementsByTagName('HTML')[0].clientHeight;
#         var layerPosition = layerScrollTop + (layerClientHeight * 0.5);
#         document.getElementById("login_layer").style.top = layerPosition + "px";
#
# 		document.getElementById("login_layer_bg").style.display = "";
# 		document.getElementById("login_layer").style.display = "";
#     	document.getElementById("login_layer").focus();
# 	}
#
# 	function closeLoginLayer() {
# 		document.getElementById("login_layer_bg").style.display = "none";
# 	    document.getElementById("login_layer").style.display = "none";
# 	}
# </script>
# <div id="login_layer_bg" style="z-index:100;display:none;position:absolute;width:100%;height:3800px;top:0px;left:0px;background-color:GRAY;filter:alpha(opacity=20);-moz-opacity:0.2;">
# <iframe frameborder="0" id="login_layer_bg_iframe" style="position:absolute;top:0px;left:0px;width:100%;height:3800px;background-color:GRAY;filter:alpha(opacity=20);-moz-opacity:0.2;" title="·Î±×ÀÎ¿µ¿ª"></iframe>
# </div>
# <div class="layerpopup" id="login_layer" style="z-index:1001; width:394px; top:400px; left:35%; display:none;">
# <div class="shadow1">
# <div class="shadow1_side">
# <div class="shadow2">
# <div class="shadow2_side">
# <div class="shadow3">
# <div class="shadow3_side">
# <div class="border_type">
# <div class="logbox_wrap">
# <p class="notice">È¸¿ø´ÔÀÇ ¾ÈÀüÇÑ ¼­ºñ½º ÀÌ¿ëÀ» À§ÇØ <strong>ºñ¹Ð¹øÈ£¸¦ È®ÀÎÇØ ÁÖ¼¼¿ä.</strong></p>
# <p class="notice02" id="layerd_notice01" style="display:none;">IP°¡ ÀÚÁÖ º¯°æµÇ´Â ³×Æ®¿öÅ© È¯°æ¿¡¼­ ·Î±×ÀÎÇÏ´Â °æ¿ì <br/><strong>IPº¸¾ÈÀ» ÇØÁ¦</strong> ÈÄ ÀÌ¿ëÇÏ½Ã±â ¹Ù¶ø´Ï´Ù.</p>
# <p class="notice02">´Ù½Ã ÇÑ¹ø <strong>ºñ¹Ð¹øÈ£ È®ÀÎ</strong> ÇÏ½Ã¸é ÀÌ¿ëÁßÀÎ È­¸éÀ¸·Î µ¹¾Æ°¡¸ç, ÀÛ¼º ÁßÀÌ´ø<br/>³»¿ëÀ» Á¤»óÀûÀ¸·Î Àü¼Û ¶Ç´Â µî·ÏÇÏ½Ç ¼ö ÀÖ½À´Ï´Ù.</p>
# <a class="closelayer" href="javascript:closeLoginLayer();" role="button"><img alt="´Ý±â" height="14" src="https://ssl.pstatic.net/static/ws/btn_close.gif" width="15"/></a>
# <div class="frame_wrap type03"><iframe frameborder="0" height="163" id="checkFrame" marginheight="0" marginwidth="0" name="checkFrame" scrolling="no" title="ºóÇÁ·¹ÀÓ" width="350"></iframe></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	function makeReturnUrl(iframeUrl) {
# 		iframeUrl = iframeUrl.replace('https://cafe.naver.com', "");
# 		var returnUrl = "https://cafe.naver.com/firenze.cafe?iframe_url=" + URLEncoder.encode(iframeUrl,"MS949");
# 		returnUrl = URLEncoder.encode(returnUrl,"MS949");
# 		return returnUrl;
# 	}
#
# 	function openWindow(target) {
#
# 		var centerWidth = (window.screen.width - 450) / 2;
# 	    var centerHeight = (window.screen.height - 500) / 2;
#
# 	    window.open(target, '_blank', 'width=440,height=500' + ',left=' + centerWidth +
# 		        ',top=' + centerHeight + ',status=no,scrollbars=no,resizable=no,menubar=no,toolbar=no,location=no');
# 	}
#
# 	function openSigningLayer(target) {
# 		var frame = document.getElementById('addressAuthFrame');
#
# 		frame.contentWindow.location.href = target;
#
#
# 		var layerScrollTop = parent.document.getElementsByTagName('HTML')[0].scrollTop;
# 		var layerClientHeight = parent.document.getElementsByTagName('HTML')[0].clientHeight;
#
# 		var layerPosition =  layerScrollTop + (layerClientHeight * 0.2);
#
#         document.getElementById("signing_layer").style.top = layerPosition + "px";
#
#         document.getElementById("signing_layer_bg").style.display = "";
# 		document.getElementById("signing_layer").style.display = "";
#     	document.getElementById("signing_layer").focus();
#
# 	}
#
# 	function closeSigningLayer() {
# 		document.getElementById("signing_layer_bg").style.display = "none";
# 	    document.getElementById("signing_layer").style.display = "none";
# 	}
# </script>
# <script charset="utf-8" src="/static/js/mycafe/javascript/lib/cafe/jindo1/OneToOneChatLauncher-1545208501000-1422.js" type="text/javascript"></script>
# <script src="/static/js/mycafe/javascript/cafe_ui-1577761219000-19251.js" type="text/javascript"></script>
# <script charset="UTF-8" src="/static/js/mycafe/javascript/widget/Clock-1545208501000-168726.js" type="text/javascript"></script>
# <script type="text/javascript">
# document.domain = "naver.com";
#
# function notiAlert(frmStr)
# {
#     open_window("", frmStr, 100, 100, "");
#     var frm = eval("document." + frmStr);
#     frm.target = frmStr;
#     try{
#         frm.submit();
#     }catch(e){}
# }
#
#
#
#
#
#
#
#
#
# function visit() {
#
#
# 	try{
# 		var ajax = new Ajax("/MyCafeVisit.nhn", {
# 			suspend : "true",
# 			method : "POST",
# 			params : { "clubid":10209062,"usingCounter":true,"ceremonyCheckNeeded":false },
# 			onLoad : cafeVisitCB
# 		});
# 		ajax.request();
# 	}catch(e){
# 	}
#
#
#
# }
# function cafeVisitCB(res) {
# 	if(res.status==200) {
# 		try{
#
# 			var counter = eval('(' + res.responseText + ')');
#
# 			if(counter == null || counter == 'undefined') {
# 				return false;
# 			}
#
#
# 				if(counter.totalVisitCount != null) { $("totalVisitCount").innerHTML = counter.totalVisitCount; }
# 				if(counter.todayVisitCount != null) { $("todayVisitCount").innerHTML = counter.todayVisitCount; }
#
#
#
# 				if(counter.visitEventResult != null && counter.visitEventResult.win == 'true') {
# 					open_window('/CafeEventPop.nhn?clubid=10209062&eventtype=2&eventresult='+counter.visitEventResult.condition+'&eventarticle='+counter.visitEventResult.eventArticleid, 'cafe_event_popup', 330, 250);
# 				}
# 				if(counter.ceremonyPassed == 'true') {
# 					open_window("/CafeCeremonyProcess.nhn?clubid=10209062&m=pass","cafe_ceremony_pass", 450, 200);
# 				}
#
#
# 			if(counter.notiList != null) {
# 				for (var i = 0; i < counter.notiList.length; i++) {
# 					if (counter.notiList[i].exposeAll == 'true' || counter.notiList[i].exposeCafe == 'true') {
# 						document.notifrm.action = counter.notiList[i].param2;
# 						document.notifrm.noticode.value = counter.notiList[i].noticode;
# 						document.notifrm.comment.innerText = counter.notiList[i].message;
#
# 						notiAlert('notifrm');
# 					}
# 				}
# 			}
# 		}catch(e){
# 		}
# 	}
# }
#
# LH.add("visit()");
#
# Function.prototype.bind = function(){
#     var f = this, a = $A(arguments), object = a.shift();
#     return function(){
#         f.apply(object, a.concat($A(arguments)));
#     }
# };
#
# function callAppView(componentid, appId) {
#     var ajax = new Ajax("/AppCafeViewAjax.nhn?clubid=10209062&appId="+appId, {
#         suspend : "true",
#         onLoad : appViewCallBack.bind(window,componentid,appId)
#     });
#     ajax.request();
# }
#
#
# function appViewCallBack(componentid, appId, res) {
#     $(componentid).innerHTML = '';
#     $(componentid).innerHTML = res.responseText;
#
#     try{
#         parentResizeIframe('cafe_main');
#     }catch(e){}
# }
#
#
#
#
#
#
#
#
#
#
#     function exchangeDisplay(s){
#         var id  = 'widget_exchange';
#         if (s == 0) {
#             Element.show(id+'0'); Element.hide(id+'1');
#             if (!$('widget_exchange0')._widget) {
#                 $('widget_exchange0')._widget =  new widget('widget_exchange0', {
#                     setUrl : '/ContentWidget.nhn?m=currency&type=2&country=EUR&iconid=8&'
#                 });
#             }
#         }else{
#             Element.hide(id+'0'); Element.show(id+'1');
#             if (!$('widget_exchange1')._widget) {
#                 $('widget_exchange1')._widget =  new widget('widget_exchange1', {
#                     setUrl : '/ContentWidget.nhn?m=currency&type=0&'
#                 });
#             }
#         }
#     }
#
#
#
# //È¯À²°è»ê
# function currency_exchange(){
#     var from    = $('ex_from').value;
#     var to      = $('ex_to').value;
#     var amount  = $('ex_amount').value;
#     amount  = amount.replace(/ |,|\t/g,'');
#
#     if(isNaN(amount) || amount == '') {
#         alert("¼ýÀÚ¸¦ ÀÔ·ÂÇÏ¼¼¿ä.");
#         $('ex_amount').value = '';
#         $('ex_amount').focus();
#         return false;
#     } else {
#         var result = ((amount * from) / to).toFixed(2);
#         $('ex_result').value = result;
#     }
# }
# LH.add("exchangeDisplay(0)");
#
#
#
#
#
#
#
#
#     var sWeatherWidgetUrl = '/ContentWidget.nhn?m=weather&iconid=2&type=2&area=11B10101';
#
#     function initWeatherWidget()
#     {
#         new widget('widget-weather', {
#             setUrl : sWeatherWidgetUrl
#         });
#     }
#     LH.add("initWeatherWidget()");
#
#
#
# LH.add("callMemberNews('visit');");
# LH.add("parentResizeIframe('cafe_main')");
# </script>
# <form action="" method="post" name="notifrm">
# <input name="clubid" type="hidden" value="10209062"/>
# <input name="noticode" type="hidden" value=""/>
# <textarea name="comment" style="display: none;" title="´ñ±Û ÆË¾÷"></textarea>
# </form>
# <script type="text/javascript">
#     oOneToOneChatLauncher.setIsCafeMember(false);
#
# 	function initAutoAndRight() {
# 		// AjaxUI
# 		// ÀÚµ¿ÃâÃ³ ±â´ÉÀÇ »ç¿ë¿©ºÎ¸¦ µÎ¹øÂ° ÆÄ¶ó¹ÌÅÍ¿¡ ÁöÁ¤ÇÕ´Ï´Ù.
# 		AutoSourcing.init( 'post_%id%' , true );
#
# 		if (false==true) {
# 			blockMouseRight();
# 		}
# 	}
# 	LH.add( "initAutoAndRight()" );
#
#
#
#     if ($Agent().IE) {
#         Ajax.initFlash("/common/flash/ajax.swf");
#     }
# </script>
# <script type="text/javascript">
# 	// CAFESUS-7781 by laziel
# 	var goFitter;
# 	var gnFitted = 0;
#
# 	function fitFrame(){
# 		if(gnFitted < 10){ // 0.5ÃÊ¾¿ 10È¸
# 			parentResizeIframe('cafe_main');
# 			goFitter = window.setTimeout('fitFrame()', 500);
# 			gnFitted++;
# 		} else {
# 			stopFitFrame();
# 		}
# 	}
#
# 	function stopFitFrame(){
# 		if(goFitter){
# 			Event.unregister(window, 'load', fitFrame);
# 			window.clearTimeout(goFitter);
# 			goFitter = gnFitted = null;
# 		}
# 	}
#
# 	Event.register(window, 'load', fitFrame);
# 	Event.register(window, 'unload', stopFitFrame);
#
# 	var bTablet = false;
# 	var oTabletHandler = new TabletHandler(bTablet);
#
#
# var cafenameTitle = "[À¯¶û]À¯·´¿©ÇàÀÇµçµçÇÑµ¿¹ÝÀÚ";
# LH.add(changeTitle(cafenameTitle + " : " +  "³×ÀÌ¹ö Ä«Æä"));
# LH.add(initTopLayerQuery());
#
#
#
# </script>
# <script type="text/javascript">
#
#
#
#
# 	function showDenyNamelessLayer() {
#
# 		var layerScrollTop = document.getElementsByTagName('HTML')[0].scrollTop;
# 		var layerClientHeight = document.getElementsByTagName('HTML')[0].clientHeight;
# 		var layerPosition = layerScrollTop + (layerClientHeight * 0.5);
# 		document.getElementById("denyNamelessLayer").style.top = layerPosition + "px";
# 		document.getElementById("denyNamelessLayer").style.display = "";
# 	}
#
#
#
# function hideDenyNamelessLayer() {
# 	document.getElementById("denyNamelessLayer").style.display = "none";
# }
#
# function redirectToCertPage() {
# 	toCertPage(encodeURIComponent(document.location.href), encodeURIComponent('https://cafe.naver.com/firenze'));
# }
# </script>
# <div class="cafetype_layer2" id="denyNamelessLayer" style="width:356px;top:0px;left:440px;margin:0;display:none;">
# <img alt="" height="24" src="https://cafe.pstatic.net/img/realname/ico_layer.gif" width="25"/>
# <h3><span>[À¯¶û]À¯·´¿©ÇàÀÇµçµçÇÑµ¿¹ÝÀÚ</span> Ä«Æä´Â<br/>½Ç¸í È®ÀÎ È¸¿ø¸¸ °¡ÀÔ ¹Þ°í ÀÖ½À´Ï´Ù.</h3>
# <p class="layer_txt">Ä«Æä¿¡ °¡ÀÔ ÇÏ½Ã·Á¸é ½Ç¸í È®ÀÎÀ» ÇØÁÖ¼¼¿ä.</p>
# <div class="btn_box">
# <a href="#" onclick="hideDenyNamelessLayer(); return false;"><img alt="´Ý±â" height="26" src="https://cafe.pstatic.net/img/realname/btn_clse_lay.gif" width="47"/></a> <a href="#" onclick="redirectToCertPage();"><img alt="½Ç¸í È®ÀÎ ÇÏ±â" height="26" src="https://cafe.pstatic.net/img/realname/btn_cfm_lay.gif" width="105"/></a>
# </div>
# <a class="btn_close" href="#" onclick="hideDenyNamelessLayer(); return false;" role="button"><img alt="´Ý±â" height="19" src="https://cafe.pstatic.net/img/btn_close_layer3.gif" width="19"/></a>
# <iframe frameborder="0" scrolling="no" style="width:400px;" title="ºóÇÁ·¹ÀÓ"></iframe>
# </div>
# </input></body>
# </html>
